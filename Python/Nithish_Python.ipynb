# %%
5+5
# Out:
# 10

# %% [markdown]
# ### Introduction

# %%
## Introduction

# %% [raw]
# ## Introduction

# %% [markdown]
# #### Introduction

# %% [raw]
# python

# %%
import keyword#
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#single line
'''add numbers'''
a+b
a
# Out:
# 5

# %%
print("hello world")
# Out:
# hello world

# %%
x=5+6+8
x
# Out:
# 19

# %%
a=5
a=7
a
# Out:
# 7

# %%
a=b=5
a
# Out:
# 5

# %%
b
# Out:
# 5

# %%
5
# Out:
# 5

# %%
a=5
b=2.3
c="Hello"

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# str

# %%
isinstance(5, bool)
# Out:
# False

# %%
str="Hello World"

# %%
str
# Out:
# 'Data mites'

# %%
str[1]
# Out:
# 'a'

# %%
str[2]
# Out:
# 't'

# %%
str[-1]
# Out:
# 's'

# %%
str[-3]
# Out:
# 't'

# %%
str[-5]
# Out:
# 'm'

# %%
str[4]
# Out:
# ' '

# %%
str[0]
# Out:
# 'H'

# %%
str[0:5]
# Out:
# 'Hello'

# %%
str[6:11]
# Out:
# 'World'

# %%
str[-1:-5]
# Out:
# ''

# %%
str[0:5:2]
# Out:
# 'Hlo'

# %%
str[:]
# Out:
# 'Hello World'

# %%
str[::-1]
# Out:
# 'dlroW olleH'

# %%
str[0:5-1]
# Out:
# 'Hell'

# %%
str[5:0-1]
# Out:
# ' Worl'

# %%
str.replace ("Hello","Namaste")
# Out:
# 'Namaste World'

# %%
del str
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 del str
#
# NameError: name 'str' is not defined

# %%
str
# Out:
# str

# %%
a="Hello"
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
Python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 Python
#
# NameError: name 'Python' is not defined

# %%
a="Hello World"

# %%
a
# Out:
# 'Hello World'

# %%
"Hello"+"World"
# Out:
# 'HelloWorld'

# %%
"Hello"+" "+"World"
# Out:
# 'Hello World'

# %%
str="hello how are you"

# %%
str
# Out:
# 'hello how are you'

# %%
"are" in str
# Out:
# True

# %%
"Hello" in str
# Out:
# False

# %%
"Hello" not in str
# Out:
# True

# %%
str="namaste how are you and how can i help u and your name and yourself"

# %%
str
# Out:
# 'namaste how are you and how can i help u and your name and yourself'

# %%
"are" in str
# Out:
# True

# %%
str.partition("and")
# Out:
# ('namaste how are you ', 'and', ' how can i help u and your name and yourself')

# %%
str.count("and")
# Out:
# 3

# %%
str.count("you")
# Out:
# 3

# %%
str.startswith("n")
# Out:
# True

# %%
str.startswith("y")
# Out:
# False

# %%
str.endswith("f")
# Out:
# True

# %%
str.endswith("y")
# Out:
# False

# %%
str.upper()
# Out:
# 'NAMASTE HOW ARE YOU AND HOW CAN I HELP U AND YOUR NAME AND YOURSELF'

# %%
str.lower()
# Out:
# 'namaste how are you and how can i help u and your name and yourself'

# %%
a="  @#@#Nithish%@#@#  "

# %%
a.strip()
# Out:
# '@#@#Nithish%@#@#'

# %%
a.strip("@#")
# Out:
# '  @#@#Nithish%@#@#  '

# %%
a.strip()
# Out:
# '@#@#Nithish%@#@#'

# %%
a=10
b=20
c=30
"cost of three pens {},{},{}".format (a,b,c)
# Out:
# 'cost of three pens 10,20,30'

# %%
f"cost of three pens {a},{b},{c}"
# Out:
# 'cost of three pens 10,20,30'

# %%
a=40
b=50
c=55
"cost of three books {},{},{}".format (a,b,c)
# Out:
# 'cost of three books 40,50,55'

# %%
f"cost of three books {a},{b},{c}"
# Out:
# 'cost of three books 40,50,55'
