# %%
a=2
b=5
c=7
"cost of pens {},{},{}".format(a,b,c)
# Out:
# 'cost of pens 2,5,7'

# %%
f"cost of 3 pens {23},{23},{22}"
# Out:
# 'cost of 3 pens 23,23,22'

# %%
len("hello")
# Out:
# 5

# %%
a=23
b=23.6
c="hello"

# %%
float(a)
# Out:
# 23.0

# %%
str(a)
# Out:
# '23'

# %%
bool(a)
# Out:
# True

# %%
z=0

# %%
bool(z)
# Out:
# False

# %%
int(b)
# Out:
# 23

# %%
bool(b)
# Out:
# True

# %%
x=0

# %%
bool(x)
# Out:
# False

# %%
str(b)
# Out:
# '23.6'

# %%
x=str(b)

# %%
type(x)
# Out:
# str

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
g=True
h=False

# %%
int(g)
# Out:
# 1

# %%
float(g)
# Out:
# 1.0

# %%
float(h)
# Out:
# 0.0

# %%
str(g)
# Out:
# 'True'

# %%
str(h)
# Out:
# 'False'

# %%
j=str(h)

# %%
type(j)
# Out:
# str

# %%
int(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 int(c)
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
d="123"

# %%
type(d)
# Out:
# str

# %%
int(d)
# Out:
# 123

# %%
type(d)
# Out:
# str

# %%
t=int(d)

# %%
type(t)
# Out:
# int

# %%
str(b)
# Out:
# '23.6'

# %%
float(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 float(c)
#
# ValueError: could not convert string to float: 'hello'

# %%
q="28.3"

# %%
float(q)
# Out:
# 28.3

# %%
bool(c)
# Out:
# True

# %%
bool(q)
# Out:
# True

# %%
String="Good Morning"

# %%
len(String)
# Out:
# 12

# %%
Len(namaste)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 Len(namaste)
#
# NameError: name 'Len' is not defined

# %%
len("namaste")
# Out:
# 7

# %%
greetings="Hello everyone"

# %%
greetings.split()
# Out:
# ['Hello', 'everyone']

# %%
g="hello everyone I am Nithish"

# %%
g.split()
# Out:
# ['hello', 'everyone', 'I', 'am', 'Nithish']

# %%
u="hello-everyone-I-am-Nithish"

# %%
u.split()
# Out:
# ['hello-everyone-I-am-Nithish']

# %%
u.split("-")
# Out:
# ['hello', 'everyone', 'I', 'am', 'Nithish']

# %%
r="nithishsiddapur@gmail.com"

# %%
r.split("@")
# Out:
# ['nithishsiddapur', 'gmail.com']

# %%
x=20

# %%
int(x)
# Out:
# 20

# %%
str(x)
# Out:
# '20'

# %%
float(x)
# Out:
# 20.0

# %%
bool(x)
# Out:
# True

# %%
t="namaste"

# %%
t=28

# %%
float(t)
# Out:
# 28.0

# %%
str(t)
# Out:
# '28'

# %%
bool(t)
# Out:
# True

# %%
int(t)
# Out:
# 28

# %%
y=28.7

# %%
int(y)
# Out:
# 28

# %%
float(y)
# Out:
# 28.7

# %%
bool(y)
# Out:
# True

# %%
str(y)
# Out:
# '28.7'

# %%
name="Nithish"
age=35
marks=92.4

# %%
a,b=10,20

# %%
name=input("Enter the name")
print("name is",name)
# Out:
# Enter the name Nithish
# name is Nithish

# %%
age=int (input("Enter the age"))
print("age is", age)
# Out:
# Enter the age 35
# age is 35

# %%
age=int (input("Enter the age"))
print("age is", age)
# Out:
# Enter the age Nithish
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 age=int (input("Enter the age"))
#       2 print("age is", age)
#
# ValueError: invalid literal for int() with base 10: 'Nithish'

# %%
age=int (input("Enter the age"))
print("age is", age)
# Out:
# Enter the age 35
# age is 35

# %%
a=50
b=60
c=a+b
print ("addition of a & b is", c)
# Out:
# addition of a & b is 110

# %%
d=a-b

# %%
print ("substraction of a & b is", d)
# Out:
# substraction of a & b is -10

# %%
e=a*b
print ("multiplication of a & b is", e)
# Out:
# multiplication of a & b is 3000

# %%
f=a/b

# %%
print ("Division of a & b is",f)
# Out:
# Division of a & b is 0.8333333333333334

# %%
a=50
b=60
c=a+b
print ("addition of a & b is", c)
print ("substraction of a & b is", d)
print ("multiplication of a & b is", e)
print ("Division of a & b is",f)
# Out:
# addition of a & b is 110
# substraction of a & b is -10
# multiplication of a & b is 3000
# Division of a & b is 0.8333333333333334

# %%
f=a//b
print ("Division of a & b is",f)
# // is used for Floor Value
# Out:
# Division of a & b is 0

# %%
f=a%b
print ("Division of a & b is",f)
# % used for reminder
# Out:
# Division of a & b is 50

# %%
n=2
m=n**2
print ("square of 2 is",m)
# Out:
# square of 2 is 4

# %%
num1=70
num2=60
u=num1==num2
print(u)

# Comparison operators (i need to find the examples, >=, <= etc)
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
'n' in "namaste"
# Out:
# True

# %%
'n' not in "namaste"
# Out:
# False

# %%
## Identity operator
# is 
# is not

# %%
a=5
b=5
a is b
# Out:
# True

# %%
a is not b
# Out:
# False

# %%
a=5
b=6
a is b
# Out:
# False

# %%
a=5
b=6
a is not b
# Out:
# True

# %%
import sys

# %% [markdown]
# sys.getsizeof("hello")
#
# # Hello occupies the below space in memory

# %%
sys.getsizeof("Nithish Chandran")
# Out:
# 57

# %% [markdown]
# ## Conditional Statement

# %%
age=int(input("Enter the age"))
if age<=18:
    print("You are not eligible to vote")
   

        #this did not work as there is no else statement
# Out:
# Enter the age 12
# You are not eligible to vote

# %%
age=int(input("Enter the age"))
if age<=18:
    print("You are not eligible to vote")
print("Eligible")
# Out:
# Enter the age 12
# You are not eligible to vote
# Eligible

# %%
age=int(input("Enter the age"))
if age<=18:
    print("You are not eligible to vote")
print("Eligible")
# Need clarification
# Out:
# Enter the age 35
# Eligible

# %%
height=int (input("Enter the Height"))
if height>=145:
    print ("You are eligible for the Sports")
# Out:
# Enter the Height 170
# You are eligible for the Sports

# %%
age=int(input("Enter the age"))
if age>=18:
    print("You are eligible to vote")
else:
    print ("Not Eligible")
# Out:
# Enter the age 13
# Not Eligible

# %%
marks=int(input("Enter the marks"))
if marks>=35:
    print("PASS")
else:
    print("FAIL")
# Out:
# Enter the marks 25
# FAIL
